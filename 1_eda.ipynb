# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
goalie_df = pd.read_csv('data/goalies2122.csv')
skater_df = pd.read_csv('data/skaters2122.csv')
team_df = pd.read_csv('data/teams2122.csv')

# %%
goalie_cols = goalie_df.columns
skater_cols = skater_df.columns
team_cols = team_df.columns

# %%
# explore the goalie data frame first

# %%
goalie_df.head()
# Out:
#    playerId  season            name team position situation  games_played  \
# 0   8475156    2021  Mikko Koskinen  EDM        G     other            45
# 1   8475156    2021  Mikko Koskinen  EDM        G       all            45
# 2   8475156    2021  Mikko Koskinen  EDM        G      5on5            45
# 3   8475156    2021  Mikko Koskinen  EDM        G      4on5            45
# 4   8475156    2021  Mikko Koskinen  EDM        G      5on4            45
#
#     icetime  xGoals  goals  unblocked_shot_attempts  xRebounds  rebounds  \
# 0    3743.0    8.19    7.0                    114.0       4.79       4.0
# 1  157718.0  129.16  136.0                   2441.0      97.08      99.0
# 2  129918.0   93.30   99.0                   1934.0      72.40      74.0
# 3   11732.0   22.73   27.0                    341.0      17.61      17.0
# 4   12325.0    3.75    2.0                     43.0       1.84       2.0
#
#    xFreeze  freeze  xOnGoal  ongoal  xPlayStopped  playStopped  \
# 0    11.89     9.0    62.87    61.0          1.53          1.0
# 1   312.31   330.0  1383.01  1397.0         45.18         51.0
# 2   253.27   276.0  1084.14  1100.0         34.33         38.0
# 3    41.81    41.0   198.62   198.0          1.38          1.0
# 4     3.94     1.0    30.39    30.0          7.60         11.0
#
#    xPlayContinuedInZone  playContinuedInZone  xPlayContinuedOutsideZone  \
# 0                 37.97                 28.0                      21.02
# 1                777.64                604.0                     551.46
# 2                602.21                457.0                     443.59
# 3                124.63                111.0                      63.57
# 4                 10.13                  8.0                      20.28
#
#    playContinuedOutsideZone  flurryAdjustedxGoals  lowDangerShots  \
# 0                      36.0                  7.64            51.0
# 1                     685.0                124.58          1403.0
# 2                     548.0                 90.57          1128.0
# 3                      70.0                 21.51           200.0
# 4                      28.0                  3.71            22.0
#
#    mediumDangerShots  highDangerShots  lowDangerxGoals  mediumDangerxGoals  \
# 0               28.0              7.0             2.16                3.48
# 1              405.0            105.0            45.27               48.39
# 2              300.0             72.0            37.32               35.85
# 3               57.0             20.0             5.07                6.57
# 4               14.0              5.0             0.61                1.77
#
#    highDangerxGoals  lowDangerGoals  mediumDangerGoals  highDangerGoals  \
# 0              2.56             4.0                3.0              0.0
# 1             35.50            49.0               53.0             34.0
# 2             20.13            40.0               43.0             16.0
# 3             11.10             5.0                6.0             16.0
# 4              1.37             0.0                0.0              2.0
#
#    blocked_shot_attempts  penalityMinutes  penalties
# 0                   28.0              0.0        0.0
# 1                  528.0              4.0        2.0
# 2                  434.0              2.0        1.0
# 3                   64.0              2.0        1.0
# 4                    2.0              0.0        0.0

# %%
goalie_df_x = goalie_df.iloc[:,8:-3]

# %%
goalie_df_x.columns
# Out:
# Index(['xGoals', 'goals', 'unblocked_shot_attempts', 'xRebounds', 'rebounds',
#        'xFreeze', 'freeze', 'xOnGoal', 'ongoal', 'xPlayStopped', 'playStopped',
#        'xPlayContinuedInZone', 'playContinuedInZone',
#        'xPlayContinuedOutsideZone', 'playContinuedOutsideZone',
#        'flurryAdjustedxGoals', 'lowDangerShots', 'mediumDangerShots',
#        'highDangerShots', 'lowDangerxGoals', 'mediumDangerxGoals',
#        'highDangerxGoals', 'lowDangerGoals', 'mediumDangerGoals',
#        'highDangerGoals'],
#       dtype='object')

# %%
goalie_df_x=goalie_df_x[['xGoals', 'goals', 'unblocked_shot_attempts', 'xRebounds', 'rebounds',
       'xFreeze', 'freeze', 'xOnGoal', 'ongoal', 'xPlayStopped', 'playStopped',
       'xPlayContinuedInZone', 'playContinuedInZone',
       'xPlayContinuedOutsideZone', 'playContinuedOutsideZone','lowDangerxGoals','lowDangerGoals','mediumDangerxGoals',
       'mediumDangerGoals','highDangerxGoals','highDangerGoals']]

# %%
no_col = [i for i in goalie_df.columns if i not in goalie_df_x.columns]

# %%
goalie_df_basic = goalie_df[no_col]

# %%
goalie_df_basic
# Out:
#      playerId  season            name team position situation  games_played  \
# 0     8475156    2021  Mikko Koskinen  EDM        G     other            45
# 1     8475156    2021  Mikko Koskinen  EDM        G       all            45
# 2     8475156    2021  Mikko Koskinen  EDM        G      5on5            45
# 3     8475156    2021  Mikko Koskinen  EDM        G      4on5            45
# 4     8475156    2021  Mikko Koskinen  EDM        G      5on4            45
# ..        ...     ...             ...  ...      ...       ...           ...
# 590   8478039    2021  Kaapo Kahkonen  SJS        G     other            36
# 591   8478039    2021  Kaapo Kahkonen  SJS        G       all            36
# 592   8478039    2021  Kaapo Kahkonen  SJS        G      5on5            36
# 593   8478039    2021  Kaapo Kahkonen  SJS        G      4on5            36
# 594   8478039    2021  Kaapo Kahkonen  SJS        G      5on4            36
#
#       icetime  flurryAdjustedxGoals  lowDangerShots  mediumDangerShots  \
# 0      3743.0                  7.64            51.0               28.0
# 1    157718.0                124.58          1403.0              405.0
# 2    129918.0                 90.57          1128.0              300.0
# 3     11732.0                 21.51           200.0               57.0
# 4     12325.0                  3.71            22.0               14.0
# ..        ...                   ...             ...                ...
# 590    2827.0                  5.85            45.0               19.0
# 591  116817.0                 93.94          1075.0              299.0
# 592   94815.0                 62.68           846.0              214.0
# 593   10178.0                 22.91           154.0               60.0
# 594    8997.0                  2.13            28.0                6.0
#
#      highDangerShots  blocked_shot_attempts  penalityMinutes  penalties
# 0                7.0                   28.0              0.0        0.0
# 1              105.0                  528.0              4.0        2.0
# 2               72.0                  434.0              2.0        1.0
# 3               20.0                   64.0              2.0        1.0
# 4                5.0                    2.0              0.0        0.0
# ..               ...                    ...              ...        ...
# 590              9.0                   20.0              0.0        0.0
# 591             93.0                  464.0              2.0        1.0
# 592             53.0                  369.0              2.0        1.0
# 593             28.0                   72.0              0.0        0.0
# 594              2.0                    3.0              0.0        0.0
#
# [595 rows x 15 columns]
